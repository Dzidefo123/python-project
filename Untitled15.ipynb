# %% [markdown]
# <a href="https://colab.research.google.com/github/Dzidefo123/python-project/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
pip install lxml

# %%
def get_data_breaches_table(url):
    # Make a GET request to the Wikipedia page
    response = requests.get(url)

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the table containing the data
    table = soup.find('table', {'class': 'wikitable'})

    # Extract the table data using pandas
    df = pd.read_html(str(table))[0]

    return df

if __name__ == "__main__":
    wikipedia_url = 'https://en.wikipedia.org/wiki/List_of_data_breaches'
    data_breaches_table = get_data_breaches_table(wikipedia_url)


# Save the table data to a CSV file
    csv_file = 'data_breaches_table.csv'
    data_breaches_table.to_csv(csv_file, index=False)

    print(f"Table data saved to '{csv_file}'.")
# Out:
# Table data saved to 'data_breaches_table.csv'.

# %%
df = pd.read_csv('/content/data_breaches_table.csv')

# %%
df.head()
# Out:
#                        Entity  Year    Records  Organization type  \
# 0       21st Century Oncology  2016    2200000         healthcare
# 1                       500px  2020   14870304  social networking
# 2       Accendo Insurance Co.  2020     175350         healthcare
# 3  Adobe Systems Incorporated  2013  152000000               tech
# 4                  Adobe Inc.  2019    7500000               tech
#
#           Method   Sources
# 0         hacked    [5][6]
# 1         hacked       [7]
# 2  poor security    [8][9]
# 3         hacked      [10]
# 4  poor security  [11][12]

# %%
df.tail()
# Out:
#                                                 Entity  Year    Records  \
# 360  Unknown agency (believed to be tied to United ...  2020  200000000
# 361  National Health Information Center (NCZI) of S...  2020     391250
# 362           50 companies and government institutions  2022    6400000
# 363                                               IKEA  2022      95000
# 364               Consumer Financial Protection Bureau  2023     256000
#
#     Organization type                  Method      Sources
# 360         financial  accidentally published        [423]
# 361        healthcare           poor security        [424]
# 362           various           poor security  [425] [426]
# 363            retail  accidentally published        [427]
# 364            bureau           poor security        [428]

# %%
df.describe()
# Out:
#           Entity  Year  Records Organization type  Method Sources
# count        365   365      363               365     365     364
# unique       342    23      263                74      27     326
# top     Facebook  2011  unknown               web  hacked    [36]
# freq           5    34       24                54     202      25

# %%
# remove sources, entity, year columns
# prioritize the severity of the data breach based on organisation type / number of records
#

# %%
df1 = df.drop('Sources', axis=1)

# %%
df1.head()
# Out:
#                        Entity  Year    Records  Organization type  \
# 0       21st Century Oncology  2016    2200000         healthcare
# 1                       500px  2020   14870304  social networking
# 2       Accendo Insurance Co.  2020     175350         healthcare
# 3  Adobe Systems Incorporated  2013  152000000               tech
# 4                  Adobe Inc.  2019    7500000               tech
#
#           Method
# 0         hacked
# 1         hacked
# 2  poor security
# 3         hacked
# 4  poor security

# %%
#convert various organisation types using one hot encoder
#

# %%
unique_organization = df['Organization type'].value_counts()

# %%
unique_organization
# Out:
# web                           54
# healthcare                    48
# financial                     38
# government                    32
# retail                        27
#                               ..
# special public corporation     1
# shopping                       1
# local search                   1
# publisher (magazine)           1
# bureau                         1
# Name: Organization type, Length: 74, dtype: int64

# %%
# find the number of 'method who are less than 10'
len(unique_organization[unique_organization < 2])
# Out:
# 48

# %%
unique_organization1 = unique_organization[unique_organization < 2]

# %%
unique_organization1
# Out:
# web, gaming                                                                 1
# various                                                                     1
# tech, web                                                                   1
# web service                                                                 1
# arts group                                                                  1
# QR code payment                                                             1
# fashion                                                                     1
# Clinical Laboratory                                                         1
# Question & Answer                                                           1
# government, database                                                        1
# Consumer Goods                                                              1
# phone accessories                                                           1
# ...

# %%
unique_organization2 = unique_organization[unique_organization > 2]

# %%
unique_organization2
# Out:
# web                   54
# healthcare            48
# financial             38
# government            32
# retail                27
# tech                  19
# academic              13
# telecoms              12
# gaming                12
# social network         8
# hotel                  8
# transport              7
# military               7
# energy                 4
# telecommunications     3
# media                  3
# telecom                3
# restaurant             3
# Name: Organization type, dtype: int64

# %%
df1['Organization type' ] = df1['Organization type'].str.strip()

# %%
rename_org = {
    'tech, web ' : 'tech',
    'web service' : 'tech',
    'web, tech' : 'tech',
    'Network Monitoring' : 'tech',
    'malware tools': 'tech',
    'information technology': 'tech',
    'software':'tech',
    'Information Security':'tech',
    'web, gaming' : 'gaming',
    'game':'gaming',
    'arts group': 'media',
    'QR code payment': 'financial',
    'financial, credit reporting': 'financial',
    'Clinical Laboratory': 'healthcare',
    'health': 'healthcare',
    'Question & Answer': 'academic',
    'government, database' : 'government',
    'educational services': 'academic',
    'banking' : 'financial',
    'web, military': 'military',
    'military, healthcare' : 'military'

 }

df1['Organization type'] = df1['Organization type'].replace(rename_org)

# %%
df1.head()
# Out:
#                        Entity  Year    Records  Organization type  \
# 0       21st Century Oncology  2016    2200000         healthcare
# 1                       500px  2020   14870304  social networking
# 2       Accendo Insurance Co.  2020     175350         healthcare
# 3  Adobe Systems Incorporated  2013  152000000               tech
# 4                  Adobe Inc.  2019    7500000               tech
#
#           Method
# 0         hacked
# 1         hacked
# 2  poor security
# 3         hacked
# 4  poor security

# %%
unique_org3 = df1['Organization type'].value_counts()

# %%
unique_org3
# Out:
# web                                                                         54
# healthcare                                                                  50
# financial                                                                   41
# government                                                                  33
# retail                                                                      27
# tech                                                                        26
# academic                                                                    15
# gaming                                                                      14
# telecoms                                                                    12
# military                                                                     9
# hotel                                                                        8
# social network                                                               8
# ...

# %%
unique_organization3
# Out:
# web, gaming                                                                 1
# various                                                                     1
# tech, web                                                                   1
# web service                                                                 1
# arts group                                                                  1
# QR code payment                                                             1
# fashion                                                                     1
# Clinical Laboratory                                                         1
# Question & Answer                                                           1
# government, database                                                        1
# Consumer Goods                                                              1
# phone accessories                                                           1
# ...

# %%
null_count = df1.isnull().sum()

# %%
null_count
# Out:
# Entity               0
# Year                 0
# Records              2
# Organization type    0
# Method               0
# dtype: int64

# %%
# delete columns with null values
df2 = df1.dropna()

# %%
nulls = df2.isnull().sum()

# %%
nulls
# Out:
# Entity               0
# Year                 0
# Records              0
# Organization type    0
# Method               0
# dtype: int64

# %%
specific_value = 'unknown'
count_unknown_in_records = df['Records'].value_counts()[specific_value]

# %%
count_unknown_in_records
# Out:
# 24

# %%
df2.head()
# Out:
#                        Entity  Year    Records  Organization type  \
# 0       21st Century Oncology  2016    2200000         healthcare
# 1                       500px  2020   14870304  social networking
# 2       Accendo Insurance Co.  2020     175350         healthcare
# 3  Adobe Systems Incorporated  2013  152000000               tech
# 4                  Adobe Inc.  2019    7500000               tech
#
#           Method
# 0         hacked
# 1         hacked
# 2  poor security
# 3         hacked
# 4  poor security

# %%
unique2 = df2['Method'].value_counts()

# %%
unique2
# Out:
# hacked                                                  201
# poor security                                            44
# lost / stolen media                                      33
# accidentally published                                   20
# inside job                                               19
# lost / stolen computer                                   16
# unknown                                                   7
# improper setting, hacked                                  2
# ransomware hacked                                         2
# poor security/inside job                                  2
# zero-day vulnerabilities                                  1
# publicly accessible Amazon Web Services (AWS) server      1
# rogue contractor                                          1
# accidentally exposed                                      1
# misconfiguration/poor security                            1
# intentionally lost                                        1
# ...

# %%
# find the number of 'method who are less than 10'
len(unique2[unique2 < 10])
# Out:
# 21

# %%
methods1 = unique2[unique2 < 10]

# %%
methods1
# Out:
# unknown                                                 7
# improper setting, hacked                                2
# ransomware hacked                                       2
# poor security/inside job                                2
# zero-day vulnerabilities                                1
# publicly accessible Amazon Web Services (AWS) server    1
# rogue contractor                                        1
# accidentally exposed                                    1
# misconfiguration/poor security                          1
# intentionally lost                                      1
# hacked/misconfiguration                                 1
# poor security / hacked                                  1
# data exposed by misconfiguration                        1
# unprotected api                                         1
# Poor security                                           1
# accidentally uploaded                                   1
# ...

# %%
df2.Method = df2.Method.apply(lambda x: 'other' if x in methods1 else x)
df2.head()
# Out:
# <ipython-input-54-53d622d43860>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.Method = df2.Method.apply(lambda x: 'other' if x in methods1 else x)
#                        Entity  Year    Records  Organization type  \
# 0       21st Century Oncology  2016    2200000         healthcare
# 1                       500px  2020   14870304  social networking
# 2       Accendo Insurance Co.  2020     175350         healthcare
# 3  Adobe Systems Incorporated  2013  152000000               tech
# 4                  Adobe Inc.  2019    7500000               tech
#
#           Method
# 0         hacked
# 1         hacked
# 2  poor security
# 3         hacked
# 4  poor security

# %%
unique3 = df2['Method'].value_counts()

# %%
unique3
# Out:
# hacked                    201
# poor security              44
# lost / stolen media        33
# other                      30
# accidentally published     20
# inside job                 19
# lost / stolen computer     16
# Name: Method, dtype: int64
